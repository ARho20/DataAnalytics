# %% [markdown]
# # Excercise 2.A Using built-in functions
# ## Lab 1. Working with names - parsing strings

# %%
test_name = ' Madison Pettis'

# %%
def parse_and_display(name):
    for i in range (len (name)):
        if name [i] == ' ':
            first = name[:i]
            last = name [i+1:]

            print("First Name:", first)
            print("Last Name:", last)

# %%
parse_and_display(test_name)
# Out:
# First Name:
# Last Name: Madison Pettis
# First Name:  Madison
# Last Name: Pettis

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']

# %%
parse_and_display(test_list[0])
# Out:
# First Name: Grace
# Last Name: Flores

# %%
parse_and_display(test_list[1])
# Out:
# First Name: JB
# Last Name: Oinonen

# %%
parse_and_display(test_list[2])
# Out:
# First Name: Ken
# Last Name: Penn

# %%
parse_and_display('Aspenne Rhoden')
# Out:
# First Name: Aspenne
# Last Name: Rhoden
